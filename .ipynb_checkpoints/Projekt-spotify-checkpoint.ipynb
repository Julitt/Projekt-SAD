# %%
# %matplotlib inline
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import numpy as np
import pandas as pd
np.set_printoptions(suppress=True)

# %% [markdown]
# 1.  Opis problemu, skąd pomysł, źródło danych
# 2. Wstępną analizę danych (histogramy, scatterploty, macierz korelacji między zmiennymi mierzonymi na skali ilorazowej, podstawowe statystyki opisowe: średnia, mediana, kwartyle, minimum, maksimum, współczynnik zmienności dla każdej zmiennej). Do wszystkiego ma być dorzucona interpretacja.
# 3. Faktyczną analizę
#
# a.       W przypadku projektu z analizy skupień (ćwiczenia 1): Grupowanie metodą k-średnich (dla różnych wartości k), wraz z oceną jakości dopasowania dostępnymi metrykami (Silhouette, Caliński-Harabasz, wewnątrzgrupowa suma kwadratów). Na podstawie analizy wybrać odpowiednie k, i zwizualizować grupowanie dla 3 wybranych zmiennych (jeśli jest ich więcej). Centra klastrów zinterpretować (‘przeciętni przedstawiciele klastra’). Przeprowadzić również analizę skupień za pomocą metody aglomeracyjnej z użyciem różnych metod łączenia klastrów (np: ‘single’, ‘average’, ‘ward’, ‘median’), dokonać porównania, przedstawić dendrogramy wraz z opisem i decyzją ile klastrów powinno zostać wykorzystanych. Dodatkowo (dla chętnych): dorzucić dodatkowy algorytm klastrowania, np. DBScan, K-Medoids, MeanShift.

# %% [markdown]
# opis problemu, skad pomysł - #TODO

# %% [markdown]
# źródło danych - https://www.kaggle.com/nadintamer/top-spotify-tracks-of-2018

# %%
data = pd.read_csv('top2018.csv')

# %%
data.head()
# Out:
#                       id                          name       artists  \
# 0  6DCZcSspjsKoFjzjrWoCd                    God's Plan         Drake
# 1  3ee8Jmje8o58CHK66QrVC                          SAD!  XXXTENTACION
# 2  0e7ipj03S05BNilyu5bRz    rockstar (feat. 21 Savage)   Post Malone
# 3  3swc6WTsr7rl9DqQKQA55  Psycho (feat. Ty Dolla $ign)   Post Malone
# 4  2G7V7zsVDxg1yRsu7Ew9R                In My Feelings         Drake
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.754   0.449  7.0    -9.211   1.0       0.1090        0.0332
# 1         0.740   0.613  8.0    -4.880   1.0       0.1450        0.2580
# 2         0.587   0.535  5.0    -6.090   0.0       0.0898        0.1170
# 3         0.739   0.559  8.0    -8.011   1.0       0.1170        0.5800
# 4         0.835   0.626  1.0    -5.833   1.0       0.1250        0.0589
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0          0.000083     0.552    0.357   77.169     198973.0             4.0
# 1          0.003720     0.123    0.473   75.023     166606.0             4.0
# 2          0.000066     0.131    0.140  159.847     218147.0             4.0
# 3          0.000000     0.112    0.439  140.124     221440.0             4.0
# 4          0.000060     0.396    0.350   91.030     217925.0             4.0

# %% [markdown]
# Usunięcie kolumn, które zawierają tekst i nie będą analizowane (spotify URI, tytuł oraz artysta)

# %%
data = data.drop(columns=['id','name','artists'])

# %%
data.describe()
# Out:
#        danceability      energy         key    loudness        mode  \
# count     100.00000  100.000000  100.000000  100.000000  100.000000
# mean        0.71646    0.659060    5.330000   -5.677640    0.590000
# std         0.13107    0.145067    3.676447    1.777577    0.494311
# min         0.25800    0.296000    0.000000  -10.109000    0.000000
# 25%         0.63550    0.562000    1.750000   -6.650500    0.000000
# 50%         0.73300    0.678000    5.000000   -5.566500    1.000000
# 75%         0.79825    0.772250    8.250000   -4.363750    1.000000
# max         0.96400    0.909000   11.000000   -2.384000    1.000000
#
#        speechiness  acousticness  instrumentalness    liveness     valence  \
# count   100.000000    100.000000        100.000000  100.000000  100.000000
# mean      0.115569      0.195701          0.001584    0.158302    0.484443
# std       0.104527      0.220946          0.013449    0.111662    0.206145
# min       0.023200      0.000282          0.000000    0.021500    0.079600
# 25%       0.045350      0.040225          0.000000    0.094675    0.341000
# 50%       0.074950      0.109000          0.000000    0.118500    0.470500
# 75%       0.137000      0.247750          0.000031    0.170750    0.641500
# max       0.530000      0.934000          0.134000    0.636000    0.931000
#
#             tempo    duration_ms  time_signature
# count  100.000000     100.000000          100.00
# mean   119.904180  205206.780000            3.98
# std     28.795984   40007.893404            0.20
# min     64.934000   95467.000000            3.00
# 25%     95.730750  184680.000000            4.00
# 50%    120.116000  205047.500000            4.00
# 75%    140.022750  221493.250000            4.00
# max    198.075000  417920.000000            5.00

# %% [markdown]
# Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.

# %%
data['energy'].hist(bins=12)
plt.title('Rozkład energy')
plt.grid(None)
plt.show()

# %% [markdown]
# The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typical range between -60 and 0 db.

# %%
data['loudness'].hist(bins=12)
plt.title('Rozkład loudness')
plt.grid(None)
plt.show()

# %% [markdown]
# A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).

# %%
data['valence'].hist(bins=12)
plt.title('Rozkład valnce')
plt.grid(None)
plt.show()

# %%
fig = plt.figure(figsize=(10,8))
ax = Axes3D(fig)
ax.scatter(data['valence'], data['energy'], data['tempo'])
ax.set_xlabel('Głośność')
ax.set_ylabel('Długość utworu')
ax.set_zlabel('Tempo')
plt.show()

# %% [markdown]
# ## Standaryzacja danych
# ### Od każdej zmiennej odejmujemy średnią, i dzielimy przez jej odchylenie standardowe

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
data[data.columns] = scaler.fit_transform(data)

# %%
data.head()
# Out:
#    danceability    energy       key  loudness      mode  speechiness  \
# 0      0.287854 -1.455314  0.456531 -1.997753  0.833616    -0.063162
# 1      0.180503 -0.319108  0.729903  0.450984  0.833616     0.282982
# 2     -0.992691 -0.859498 -0.090213 -0.233147 -1.199593    -0.247772
# 3      0.172835 -0.693224  0.729903 -1.319276  0.833616     0.013759
# 4      0.908957 -0.229043 -1.183701 -0.087840  0.833616     0.090680
#
#    acousticness  instrumentalness  liveness   valence     tempo  duration_ms  \
# 0     -0.739184         -0.112147  3.543567 -0.621334 -1.491544    -0.156599
# 1      0.283383          0.159656 -0.317744 -0.055789 -1.566444    -0.969690
# 2     -0.357995         -0.113440 -0.245738 -1.679294  1.394085     0.325071
# 3      1.748092         -0.118343 -0.416751 -0.221552  0.705712     0.407795
# 4     -0.622280         -0.113859  2.139454 -0.655462 -1.007767     0.319494
#
#    time_signature
# 0        0.100504
# 1        0.100504
# 2        0.100504
# 3        0.100504
# 4        0.100504

# %% [markdown]
# ### Klastrowanie metodą k-średnich

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=4)
kmeans.fit(data)
print(kmeans)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.labels_
# Out:
# array([2, 1, 2, 2, 3, 2, 3, 3, 1, 3, 3, 2, 3, 2, 3, 3, 3, 3, 1, 1, 3, 3,
#        3, 1, 3, 3, 2, 1, 1, 2, 1, 3, 2, 2, 3, 1, 3, 3, 2, 2, 1, 3, 3, 0,
#        3, 3, 3, 3, 3, 2, 1, 3, 2, 1, 3, 1, 3, 3, 1, 3, 3, 1, 1, 2, 3, 2,
#        3, 3, 3, 3, 3, 3, 3, 1, 2, 2, 3, 3, 3, 1, 2, 1, 1, 3, 2, 1, 2, 1,
#        1, 1, 3, 1, 1, 2, 1, 2, 2, 3, 2, 2])

# %%
kmeans.cluster_centers_
# Out:
# array([[-0.85466845,  1.12886239, -1.45707297,  0.47755747,  0.83361577,
#         -0.69006625, -0.85968084,  9.89557074, -0.10172617, -0.957736  ,
#          1.67853626, -0.45367952,  0.10050378],
#        [ 0.73912681, -0.468703  ,  0.19328416, -0.67493234, -0.14533681,
#          0.92644606, -0.04331178, -0.0591744 , -0.37714829,  0.05652544,
#          0.20620128, -0.49547247,  0.10050378],
#        [-0.84493606, -0.70708049,  0.07801617, -0.71284378,  0.442614  ,
#         -0.37683582,  0.54566097, -0.11728783,  0.15617916, -0.90873834,
#          0.19064597,  0.24305882, -0.47932573],
#        [ 0.062317  ,  0.65022199, -0.12587   ,  0.78868596, -0.18298883,
#         -0.31578796, -0.26430622, -0.11409518,  0.13530591,  0.50127709,
#         -0.26527752,  0.16330233,  0.20974702]])

# %%
scaler.inverse_transform(kmeans.cluster_centers_)
# Out:
# array([[-0.85466845,  1.12886239, -1.45707297,  0.47755747,  0.83361577,
#         -0.69006625, -0.85968084,  9.89557074, -0.10172617, -0.957736  ,
#          1.67853626, -0.45367952,  0.10050378],
#        [ 0.73912681, -0.468703  ,  0.19328416, -0.67493234, -0.14533681,
#          0.92644606, -0.04331178, -0.0591744 , -0.37714829,  0.05652544,
#          0.20620128, -0.49547247,  0.10050378],
#        [-0.84493606, -0.70708049,  0.07801617, -0.71284378,  0.442614  ,
#         -0.37683582,  0.54566097, -0.11728783,  0.15617916, -0.90873834,
#          0.19064597,  0.24305882, -0.47932573],
#        [ 0.062317  ,  0.65022199, -0.12587   ,  0.78868596, -0.18298883,
#         -0.31578796, -0.26430622, -0.11409518,  0.13530591,  0.50127709,
#         -0.26527752,  0.16330233,  0.20974702]])

# %%
fig = plt.figure(figsize=(10,8))
ax = Axes3D(fig)

ax.scatter(
    data['valence'],
    data['energy'],
    data['tempo'],
    c=kmeans.labels_
)
plt.title('Wykres punktowy')
plt.show()
